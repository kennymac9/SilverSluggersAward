# %%
#!/usr/bin/env python
# coding: utf-8

import pandas as pd, numpy as np, matplotlib, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn import preprocessing
from sklearn import linear_model
# %matplotlib inline


# In[237]:


allData = pd.read_csv('all-np14-16.csv')


# In[238]:


# Some preprocessing on the column names
allData.astype({'Season': 'category'}).dtypes # set season to category instead of int
allData.set_index(['playerid', 'Name'])

# drop NaN values, which only come into play for pitchers running the bases (a very atypical occurrence)
allData = allData.dropna()

# sort all the rows by player ID first, then season. Makes it easier to figure out which player played which seasons
allData = allData.sort_values(by=['playerid', 'Season'])

# %%
#!/usr/bin/env python
# coding: utf-8

# Runs

# In[236]:


import pandas as pd, numpy as np, matplotlib, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
import seaborn as seabornInstance 
from sklearn.svm import LinearSVR
from sklearn import metrics
from sklearn import preprocessing
from sklearn import linear_model
# %matplotlib inline


# In[237]:

allData = pd.read_csv('all-np14-16.csv')


# Some preprocessing on the column names
allData.astype({'Season': 'category'}).dtypes # set season to category instead of int
allData.set_index(['playerid', 'Name'])

# drop NaN values, which only come into play for pitchers running the bases (a very atypical occurrence)
allData = allData.dropna()

# dictionary assigning number of years in our data set played to each player
playerYears = dict() # dict of {'player ID': 'years in our data set that they played (1, 2, or 3)'}
pid, yearsPlayed = np.unique(allData['playerid'], return_counts=True)
for i in range(len(pid)):
    playerYears[pid[i]] = yearsPlayed[i]

# dictionary assigning names to player IDs
playerNames = dict() # dict where key is player ID, value is player name
# Assign each player ID to a name for future purposes
for i, r in allData.iterrows():
    playerNames[r['playerid']] = r['Name']

# assigns weights to each player and the data for that year. If played 2016-18, keep the weights of 0.6, 0.3, 0.1. If played two years, 0.7 and 0.3. If only played one year, assign 1 for now
for index, row in allData.iterrows():
    if playerYears[row['playerid']] == 3:
        continue
    elif playerYears[row['playerid']] == 2: # played in 16-17 or 17-18
        played1617 = False
        if row['Season'] == 2014:
            played1617 = True
            allData.set_value(index, 'weight', 0.3)
        elif row['Season'] == 2015:
            if played1617:
                allData.set_value(index, 'weight', 0.7)
            else:
                allData.set_value(index, 'weight', 0.3)
        else:
            allData.set_value(index, 'weight', 0.7)
    else:
        allData.set_value(index, 'weight', 1)

# sort all the rows by player ID first, then season. Makes it easier to figure out which player played which seasons
allData = allData.sort_values(by=['playerid', 'Season'])

# scale all relevant stats
allData[['wRC', 'PA', 'H', 'AB', 'RBI', 'G', '2B']] = preprocessing.scale(allData[['wRC', 'PA', 'H', 'AB', 'RBI', 'G', '2B']])

# assign X and Y sets for regression
X = allData[['wRC', 'PA', 'H', 'AB', 'RBI', 'G', '2B']].values
Y = allData[['R']].values

# add newly calculated weighted stats to our dataframe as columns
allData['weightWRC'] = allData['weight']*allData['wRC']
allData['weightPA'] = allData['weight']*allData['PA']
allData['weightH'] = allData['weight']*allData['H']
allData['weightAB'] = allData['weight']*allData['AB']
allData['weightRBI'] = allData['weight']*allData['RBI']
allData['weightG'] = allData['weight']*allData['G']
allData['weight2B'] = allData['weight']*allData['2B']

# sum up weighted averages by player, so that all years are combined
weightedRunStats2017 = allData.groupby('playerid', as_index=False).sum()
weightedRunStats2017 = weightedRunStats2017[['playerid', 'weightWRC', 'weightPA', 'weightH', 'weightAB', 'weightRBI', 'weightG', 'weight2B']]

# we lost player names when doing the group by and sum, so get the player names and put it back in our new data frame
names = []
for i in pid:
    names.append(playerNames[i])
weightedRunStats2017['Name'] = names
weightedRunStats2017['Season'] = 2017

# move name and season columns to the front of the dataframe
cols = weightedRunStats2017.columns.tolist()
cols = cols[-2:] + cols[:-2]
weightedRunStats2017 = weightedRunStats2017[cols]


# In[239]:


# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X, Y)


# In[240]:


X_2017 = weightedRunStats2017[['weightWRC', 'weightPA', 'weightH', 'weightAB', 'weightRBI', 'weightG', 'weight2B']].values
y_pred = regressor.predict(X_2017)


# In[241]:


y_pred_list = [] # list of y_pred so we can add it to a dataframe
for i in range(len(y_pred)):
    y_pred_list.append(y_pred[i][0])

weightedRunStats2017['linearRegRuns'] = y_pred_list

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regr = LinearSVR(random_state=0)
regr.fit(X, Y)

# In[240]:
y_pred = regr.predict(X_2017)
weightedRunStats2017['linearSVRRuns'] = y_pred

regr = SVR()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRunStats2017['svrRuns'] = y_pred

regr = linear_model.BayesianRidge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRunStats2017['BayesRidgeRuns'] = y_pred

regr = linear_model.HuberRegressor()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRunStats2017['HuberRegressorRuns'] = y_pred

regr = linear_model.Ridge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRunStats2017['RidgeRuns'] = y_pred

regr = linear_model.ARDRegression()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRunStats2017['ARDRegressionRuns'] = y_pred

weightedRunStats2017 = weightedRunStats2017.sort_values(by=['linearSVRRuns'], ascending=False)
print(weightedRunStats2017)
# weightedRunStats2017.to_csv('RunsPredicted.csv')
# Out:
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:62: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:53: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:60: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:58: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                Name  Season  playerid  weightWRC  weightPA   weightH  \
# 350      Mike Trout    2017     10155   2.907037  1.522083  1.555531
# 171  Josh Donaldson    2017      5038   2.643602  1.646237  1.471707
# 140      Joey Votto    2017      4314   2.621649  1.250372  1.387883
# 192     Jose Altuve    2017      5417   2.237472  1.677439  2.472943
# 483     Kris Bryant    2017     15429   2.394802  1.525983  1.478692
# ..              ...     ...       ...        ...       ...       ...
# 43     Reed Johnson    2017      1702  -1.403059 -1.615591 -1.441190
# 0       Jose Molina    2017        25  -1.805530 -1.316579 -1.534328
# 249     Tyler Moore    2017      7244  -1.476235 -1.622092 -1.580897
# 156      John Baker    2017      4756  -1.622588 -1.570090 -1.650751
# 35       Mark Ellis    2017      1443  -1.732353 -1.609091 -1.720604
#
#      weightAB  weightRBI   weightG  weight2B  linearRegRuns  linearSVRRuns  \
# 350  1.143230   1.898128  1.341771  1.249693     108.392376     106.947307
# 171  1.367201   2.215887  1.253218  1.448839     106.139032     103.240701
# 140  0.831554   1.357938  0.987561  1.165841     100.435024     100.806155
# 192  1.718018   1.310274  1.334959  2.213981      98.821257      99.403358
# 483  1.344007   2.017288  1.171478  1.364988     102.216947      98.956300
# ..        ...        ...       ...       ...            ...            ...
# 43  -1.575600  -1.005395 -0.218118 -0.605514      13.210130      16.175345
# 0   -1.300165  -1.601194 -1.342056 -1.968096      15.432793      15.528188
# 249 -1.575600  -0.925956 -0.763057 -0.919956      13.776732      15.015253
# 156 -1.611841  -1.402594 -1.750760 -1.444026      13.394189      14.453692
# 35  -1.640834  -1.521754 -1.580467 -1.548840      11.772398      12.825311
#
#        svrRuns  BayesRidgeRuns  HuberRegressorRuns   RidgeRuns  \
# 350  92.480065      108.512559          107.717601  108.788716
# 171  92.714107      106.101822          105.306708  105.929860
# 140  90.998081      100.766243           99.901523  101.656729
# 192  89.351568       98.913770           98.362039   99.203879
# 483  93.430994      102.081266          101.411263  101.639029
# ..         ...             ...                 ...         ...
# 43   26.813201       13.294159           13.909073   13.596365
# 0    25.873187       15.520693           15.482352   15.770943
# 249  22.827250       13.771324           14.171913   13.795624
# 156  22.881637       13.594692           13.437610   14.176664
# 35   23.441752       11.943033           11.899728   12.440004
#
#      ARDRegressionRuns
# 350         108.441630
# 171         106.038611
# 140         100.624704
# 192          98.915350
# 483         102.053965
# ..                 ...
# 43           13.727646
# 0            15.354948
# 249          14.038392
# 156          13.439262
# 35           11.845276
#
# [499 rows x 17 columns]

# %%
allData = pd.read_csv('all-np14-16.csv')


# In[238]:


# Some preprocessing on the column names
allData.astype({'Season': 'category'}).dtypes # set season to category instead of int
allData.set_index(['playerid', 'Name'])

# drop NaN values, which only come into play for pitchers running the bases (a very atypical occurrence)
allData = allData.dropna()

# dictionary assigning number of years in our data set played to each player
playerYears = dict() # dict of {'player ID': 'years in our data set that they played (1, 2, or 3)'}
pid, yearsPlayed = np.unique(allData['playerid'], return_counts=True)
for i in range(len(pid)):
    playerYears[pid[i]] = yearsPlayed[i]

# dictionary assigning names to player IDs
playerNames = dict() # dict where key is player ID, value is player name
# Assign each player ID to a name for future purposes
for i, r in allData.iterrows():
    playerNames[r['playerid']] = r['Name']

# assigns weights to each player and the data for that year. If played 2016-18, keep the weights of 0.6, 0.3, 0.1. If played two years, 0.7 and 0.3. If only played one year, assign 1 for now
for index, row in allData.iterrows():
    if playerYears[row['playerid']] == 3:
        continue
    elif playerYears[row['playerid']] == 2: # played in 16-17 or 17-18
        played1617 = False
        if row['Season'] == 2014:
            played1617 = True
            allData.set_value(index, 'weight', 0.3)
        elif row['Season'] == 2015:
            if played1617:
                allData.set_value(index, 'weight', 0.7)
            else:
                allData.set_value(index, 'weight', 0.3)
        else:
            allData.set_value(index, 'weight', 0.7)
    else:
        allData.set_value(index, 'weight', 1)

# sort all the rows by player ID first, then season. Makes it easier to figure out which player played which seasons
allData = allData.sort_values(by=['playerid', 'Season'])

# scale relevants stats
allData[['BABIP', 'OBP', 'wOBA', 'OPS', 'wRC+', 'wRAA', '1B']] = preprocessing.scale(allData[['BABIP', 'OBP', 'wOBA', 'OPS', 'wRC+', 'wRAA', '1B']])

# assign X and Y sets for regression
X = allData[['BABIP', 'OBP', 'wOBA', 'OPS', 'wRC+', 'wRAA', '1B']].values
Y = allData[['AVG']].values

# dictionary assigning number of years in our data set played to each player
playerYears = dict() # dict of {'player ID': 'years in our data set that they played (1, 2, or 3)'}
pid, yearsPlayed = np.unique(allData['playerid'], return_counts=True)
for i in range(len(pid)):
    playerYears[pid[i]] = yearsPlayed[i]

# dictionary assigning names to player IDs
playerNames = dict() # dict where key is player ID, value is player name
# Assign each player ID to a name for future purposes
for i, r in allData.iterrows():
    playerNames[r['playerid']] = r['Name']

# add newly calculated weighted stats to our dataframe as columns
allData['weightBABIP'] = allData['weight']*allData['BABIP']
allData['weightOBP'] = allData['weight']*allData['OBP']
allData['weightwOBA'] = allData['weight']*allData['wOBA']
allData['weightOPS'] = allData['weight']*allData['OPS']
allData['weightwRC+'] = allData['weight']*allData['wRC+']
allData['weightwRAA'] = allData['weight']*allData['wRAA']
allData['weight1B'] = allData['weight']*allData['1B']

# sum up weighted averages by player, so that all years are combined
weightedAvgStats2017 = allData.groupby('playerid', as_index=False).sum()
weightedAvgStats2017 = weightedAvgStats2017[['playerid', 'weightBABIP', 'weightOBP', 'weightwOBA', 'weightOPS', 'weightwRC+', 'weightwRAA', 'weight1B']]

# we lost player names when doing the group by and sum, so get the player names and put it back in our new data frame
names = []
for i in pid:
    names.append(playerNames[i])
weightedAvgStats2017['Name'] = names
weightedAvgStats2017['Season'] = 2017

# move name and season columns to the front of the dataframe
cols = weightedAvgStats2017.columns.tolist()
cols = cols[-2:] + cols[:-2]
weightedAvgStats2017 = weightedAvgStats2017[cols]


# In[13]:


# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X, Y)


# In[14]:


X_2017 = weightedAvgStats2017[['weightBABIP', 'weightOBP', 'weightwOBA', 'weightOPS', 'weightwRC+', 'weightwRAA', 'weight1B']].values
y_pred = regressor.predict(X_2017)


# In[15]:


y_pred_list = [] # list of y_pred so we can add it to a dataframe
for i in range(len(y_pred)):
    y_pred_list.append(y_pred[i][0])

weightedAvgStats2017['linearRegAVG'] = y_pred_list

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regr = LinearSVR(random_state=0)
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedAvgStats2017['linearSvrAVG'] = y_pred

regr = SVR()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedAvgStats2017['svrAVG'] = y_pred

regr = linear_model.BayesianRidge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedAvgStats2017['BayesRidgeAVG'] = y_pred

regr = linear_model.HuberRegressor()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedAvgStats2017['HuberRegressorAVG'] = y_pred

regr = linear_model.Ridge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedAvgStats2017['RidgeAVG'] = y_pred

regr = linear_model.ARDRegression()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedAvgStats2017['ARDRegressionAVG'] = y_pred


weightedAvgStats2017 = weightedAvgStats2017.sort_values(by=['linearSvrAVG'], ascending=False)
print(weightedAvgStats2017)
# weightedAvgStats2017.to_csv('AVGPredictions.csv')
# Out:
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                  Name  Season  playerid  weightBABIP  weightOBP  weightwOBA  \
# 140        Joey Votto    2017      4314     1.623810   3.286242    2.509086
# 350        Mike Trout    2017     10155     1.621092   2.881775    2.608619
# 305  Paul Goldschmidt    2017      9218     1.770568   2.705177    2.051771
# 47     Miguel Cabrera    2017      1744     1.368344   2.369071    2.237387
# 333       DJ LeMahieu    2017      9874     1.971680   1.901941    1.166732
# ..                ...     ...       ...          ...        ...         ...
# 371          Mike Olt    2017     10698    -2.664768  -2.100001   -1.305458
# 11     J.P. Arencibia    2017       697    -2.882186  -2.356353   -1.305458
# 8         Raul Ibanez    2017       607    -2.827832  -1.644264   -1.762773
# 35         Mark Ellis    2017      1443    -2.066867  -1.957583   -2.865709
# 0         Jose Molina    2017        25    -1.849449  -2.612706   -3.296123
#
#      weightOPS  weightwRC+  weightwRAA  weight1B  linearRegAVG  linearSvrAVG  \
# 140   2.525867    2.361761    3.390196  1.167920      0.322358      0.343753
# 350   2.683331    2.764769    3.639093  1.031227      0.321125      0.342597
# 305   2.143304    1.741444    2.771125  1.204594      0.320770      0.338935
# 47    2.361006    2.203718    2.784521  1.381296      0.319231      0.337585
# 333   1.107637    0.469202    1.461063  2.221460      0.321071      0.333063
# ..         ...         ...         ...       ...           ...           ...
# 371  -1.351546   -1.225804   -0.826256 -1.802662      0.178028      0.165811
# 11   -1.309274   -1.344336   -0.741645 -1.769322      0.174572      0.161824
# 8    -1.932788   -1.581400   -1.122394 -1.502603      0.173849      0.160655
# 35   -2.809935   -2.766719   -1.333922 -1.469263      0.175605      0.159114
# 0    -3.327769   -3.122314   -1.792232 -1.069185      0.174492      0.154768
#
#      svrAVG  BayesRidgeAVG  HuberRegressorAVG  RidgeAVG  ARDRegressionAVG
# 140   0.254       0.321832           0.322267  0.321867          0.322434
# 350   0.254       0.320320           0.320817  0.320373          0.322788
# 305   0.254       0.320267           0.320851  0.320301          0.320458
# 47    0.254       0.318608           0.319045  0.318649          0.319081
# 333   0.254       0.321532           0.321427  0.321504          0.322023
# ..      ...            ...                ...       ...               ...
# 371   0.254       0.178661           0.178611  0.178616          0.183553
# 11    0.254       0.175334           0.175219  0.175281          0.181265
# 8     0.254       0.174393           0.174271  0.174354          0.177575
# 35    0.254       0.175174           0.176018  0.175200          0.178631
# 0     0.254       0.174411           0.174873  0.174414          0.179949
#
# [499 rows x 17 columns]

# %%
allData = pd.read_csv('all-np14-16.csv')


# In[238]:


# Some preprocessing on the column names
allData.astype({'Season': 'category'}).dtypes # set season to category instead of int
allData.set_index(['playerid', 'Name'])

# drop NaN values, which only come into play for pitchers running the bases (a very atypical occurrence)
allData = allData.dropna()

# dictionary assigning number of years in our data set played to each player
playerYears = dict() # dict of {'player ID': 'years in our data set that they played (1, 2, or 3)'}
pid, yearsPlayed = np.unique(allData['playerid'], return_counts=True)
for i in range(len(pid)):
    playerYears[pid[i]] = yearsPlayed[i]

# dictionary assigning names to player IDs
playerNames = dict() # dict where key is player ID, value is player name
# Assign each player ID to a name for future purposes
for i, r in allData.iterrows():
    playerNames[r['playerid']] = r['Name']

# assigns weights to each player and the data for that year. If played 2016-18, keep the weights of 0.6, 0.3, 0.1. If played two years, 0.7 and 0.3. If only played one year, assign 1 for now
for index, row in allData.iterrows():
    if playerYears[row['playerid']] == 3:
        continue
    elif playerYears[row['playerid']] == 2: # played in 16-17 or 17-18
        played1617 = False
        if row['Season'] == 2014:
            played1617 = True
            allData.set_value(index, 'weight', 0.3)
        elif row['Season'] == 2015:
            if played1617:
                allData.set_value(index, 'weight', 0.7)
            else:
                allData.set_value(index, 'weight', 0.3)
        else:
            allData.set_value(index, 'weight', 0.7)
    else:
        allData.set_value(index, 'weight', 1)


# sort all the rows by player ID first, then season. Makes it easier to figure out which player played which seasons
allData = allData.sort_values(by=['playerid', 'Season'])

# scale relevants stats
allData[['RBI', 'ISO', 'wRC', 'SLG', 'R', 'HR/FB', 'OPS']] = preprocessing.scale(allData[['RBI', 'ISO', 'wRC', 'SLG', 'R', 'HR/FB', 'OPS']])

# assign X and Y sets for regression
X = allData[['RBI', 'ISO', 'wRC', 'SLG', 'R', 'HR/FB', 'OPS']].values
Y = allData[['HR']].values

# add newly calculated weighted stats to our dataframe as columns
allData['weightRBI'] = allData['weight']*allData['RBI']
allData['weightISO'] = allData['weight']*allData['ISO']
allData['weightwRC'] = allData['weight']*allData['wRC']
allData['weightSLG'] = allData['weight']*allData['SLG']
allData['weightR'] = allData['weight']*allData['R']
allData['weightHRFB'] = allData['weight']*allData['HR/FB']
allData['weightOPS'] = allData['weight']*allData['OPS']

# sum up weighted averages by player, so that all years are combined
weightedHRStats2017 = allData.groupby('playerid', as_index=False).sum()
weightedHRStats2017 = weightedHRStats2017[['playerid', 'weightRBI', 'weightISO', 'weightwRC', 'weightSLG', 'weightR', 'weightHRFB', 'weightOPS']]

# we lost player names when doing the group by and sum, so get the player names and put it back in our new data frame
names = []
for i in pid:
    names.append(playerNames[i])
weightedHRStats2017['Name'] = names
weightedHRStats2017['Season'] = 2017

# move name and season columns to the front of the dataframe
cols = weightedHRStats2017.columns.tolist()
cols = cols[-2:] + cols[:-2]
weightedHRStats2017 = weightedHRStats2017[cols]


# In[13]:


# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X, Y)


# In[14]:


X_2017 = weightedHRStats2017[['weightRBI', 'weightISO', 'weightwRC', 'weightSLG', 'weightR', 'weightHRFB', 'weightOPS']].values
y_pred = regressor.predict(X_2017)


# In[15]:


y_pred_list = [] # list of y_pred so we can add it to a dataframe
for i in range(len(y_pred)):
    y_pred_list.append(y_pred[i][0])

weightedHRStats2017['linearRegHR'] = y_pred_list

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regr = LinearSVR(random_state=0)
regr.fit(X, Y)

# In[240]:

y_pred = regr.predict(X_2017)
weightedHRStats2017['linearSvrHR'] = y_pred

regr = SVR()
regr.fit(X, Y)

# In[240]:

y_pred = regr.predict(X_2017)
weightedHRStats2017['SvrHR'] = y_pred

regr = linear_model.BayesianRidge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedHRStats2017['BayesRidgeHR'] = y_pred

regr = linear_model.HuberRegressor()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedHRStats2017['HuberRegressorHR'] = y_pred

regr = linear_model.Ridge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedHRStats2017['RidgeHR'] = y_pred

regr = linear_model.ARDRegression()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedHRStats2017['ARDRegressionHR'] = y_pred

weightedHRStats2017 = weightedHRStats2017.sort_values(by=['linearSvrHR'], ascending=False)
print(weightedHRStats2017)
# weightedHRStats2017.to_csv('HRPredictions.csv')
# Out:
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#                   Name  Season  playerid  weightRBI  weightISO  weightwRC  \
# 67   Edwin Encarnacion    2017      2151   2.740189   2.179884   2.065507
# 75         Nelson Cruz    2017      2434   2.041119   2.067490   2.178931
# 13         David Ortiz    2017       745   2.728273   2.566815   2.222837
# 171     Josh Donaldson    2017      5038   2.215887   1.975363   2.643602
# 327      Nolan Arenado    2017      9777   2.962621   2.196467   2.080143
# ..                 ...     ...       ...        ...        ...        ...
# 41     Shane Victorino    2017      1677  -1.720353  -1.680216  -1.403059
# 399         Tyler Holt    2017     11391  -1.482034  -1.698641  -1.293294
# 123      Joaquin Arias    2017      3817  -1.402594  -1.956595  -1.512824
# 450  Munenori Kawasaki    2017     13047  -1.323154  -2.122423  -1.110353
# 318       Craig Gentry    2017      9571  -1.521754  -2.196124  -1.220118
#
#      weightSLG   weightR  weightHRFB  weightOPS  HRsPredicted  linearSvrHR  \
# 67    1.893189  1.781236    1.559455   1.780821     36.507670    35.418790
# 75    2.129408  1.706095    2.579794   1.942512     36.025723    35.286504
# 13    2.632658  0.950507    1.271243   2.556515     35.769032    34.711758
# 171   1.984155  2.783120    1.425287   2.128509     34.880094    34.002366
# 327   2.264391  2.173641    0.910149   1.897069     35.271186    33.968872
# ..         ...       ...         ...        ...           ...          ...
# 41   -1.733734 -1.395572   -1.569472  -1.383250     -4.138692    -3.750289
# 399  -1.675046 -1.312082   -1.867623  -1.150753     -4.630191    -4.210127
# 123  -1.601686 -1.437318   -1.867623  -1.594611     -5.076309    -4.846805
# 450  -1.675046 -0.894630   -1.867623  -1.150753     -5.692310    -5.163905
# 318  -1.777750 -0.602414   -1.867623  -1.309274     -6.585320    -6.044735
#
#          SvrHR
# 67   37.225578
# 75   35.840682
# 13   31.362560
# 171  34.265386
# 327  34.030934
# ..         ...
# 41    0.899737
# 399   0.486897
# 123   0.778280
# 450   0.325764
# 318   0.389870
#
# [499 rows x 13 columns]
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
allData = pd.read_csv('all-np14-16.csv')


# In[238]:


# Some preprocessing on the column names
allData.astype({'Season': 'category'}).dtypes # set season to category instead of int
allData.set_index(['playerid', 'Name'])

# drop NaN values, which only come into play for pitchers running the bases (a very atypical occurrence)
allData = allData.dropna()

# dictionary assigning number of years in our data set played to each player
playerYears = dict() # dict of {'player ID': 'years in our data set that they played (1, 2, or 3)'}
pid, yearsPlayed = np.unique(allData['playerid'], return_counts=True)
for i in range(len(pid)):
    playerYears[pid[i]] = yearsPlayed[i]

# dictionary assigning names to player IDs
playerNames = dict() # dict where key is player ID, value is player name
# Assign each player ID to a name for future purposes
for i, r in allData.iterrows():
    playerNames[r['playerid']] = r['Name']

# assigns weights to each player and the data for that year. If played 2016-18, keep the weights of 0.6, 0.3, 0.1. If played two years, 0.7 and 0.3. If only played one year, assign 1 for now
for index, row in allData.iterrows():
    if playerYears[row['playerid']] == 3:
        continue
    elif playerYears[row['playerid']] == 2: # played in 16-17 or 17-18
        played1617 = False
        if row['Season'] == 2014:
            played1617 = True
            allData.set_value(index, 'weight', 0.3)
        elif row['Season'] == 2015:
            if played1617:
                allData.set_value(index, 'weight', 0.7)
            else:
                allData.set_value(index, 'weight', 0.3)
        else:
            allData.set_value(index, 'weight', 0.7)
    else:
        allData.set_value(index, 'weight', 1)


# sort all the rows by player ID first, then season. Makes it easier to figure out which player played which seasons
allData = allData.sort_values(by=['playerid', 'Season'])

# scale all relevant stats
allData[['wOBA', 'wRC+', 'SLG', 'wRAA', 'OBP', 'ISO', 'HR']] = preprocessing.scale(allData[['wOBA', 'wRC+', 'SLG', 'wRAA', 'OBP', 'ISO', 'HR']])

# assign X and Y sets for regression
X = allData[['wOBA', 'wRC+', 'SLG', 'wRAA', 'OBP', 'ISO', 'HR']].values
Y = allData[['OPS']].values


# add newly calculated weighted stats to our dataframe as columns
allData['weightwOBA'] = allData['weight']*allData['wOBA']
allData['weightwRC+'] = allData['weight']*allData['wRC+']
allData['weightSLG'] = allData['weight']*allData['SLG']
allData['weightwRAA'] = allData['weight']*allData['wRAA']
allData['weightOBP'] = allData['weight']*allData['OBP']
allData['weightISO'] = allData['weight']*allData['ISO']
allData['weightHR'] = allData['weight']*allData['HR']

# sum up weighted averages by player, so that all years are combined
weightedOPSStats2017 = allData.groupby('playerid', as_index=False).sum()
weightedOPSStats2017 = weightedOPSStats2017[['playerid', 'weightwOBA', 'weightwRC+', 'weightSLG', 'weightwRAA', 'weightOBP', 'weightISO', 'weightHR']]

# we lost player names when doing the group by and sum, so get the player names and put it back in our new data frame
names = []
for i in pid:
    names.append(playerNames[i])
weightedOPSStats2017['Name'] = names
weightedOPSStats2017['Season'] = 2017

# move name and season columns to the front of the dataframe
cols = weightedOPSStats2017.columns.tolist()
cols = cols[-2:] + cols[:-2]
weightedOPSStats2017 = weightedOPSStats2017[cols]


# In[239]:


# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X, Y)


# In[240]:


X_2017 = weightedOPSStats2017[['weightwOBA', 'weightwRC+', 'weightSLG', 'weightwRAA', 'weightOBP', 'weightISO', 'weightHR']].values
y_pred = regressor.predict(X_2017)


# In[241]:


y_pred_list = [] # list of y_pred so we can add it to a dataframe
for i in range(len(y_pred)):
    y_pred_list.append(y_pred[i][0])

weightedOPSStats2017['linearRegOPS'] = y_pred_list

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regr = LinearSVR(random_state=0)
regr.fit(X, Y)

# In[240]:

y_pred = regr.predict(X_2017)
weightedOPSStats2017['linearSvrOPS'] = y_pred

regr = SVR()
regr.fit(X, Y)

# In[240]:

y_pred = regr.predict(X_2017)
weightedOPSStats2017['svrOPS'] = y_pred

regr = linear_model.BayesianRidge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedOPSStats2017['BayesRidgeOPS'] = y_pred

regr = linear_model.HuberRegressor()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedOPSStats2017['HuberRegressorOPS'] = y_pred

regr = linear_model.Ridge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedOPSStats2017['RidgeOPS'] = y_pred

regr = linear_model.ARDRegression()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedOPSStats2017['ARDRegressionOPS'] = y_pred


weightedOPSStats2017 = weightedOPSStats2017.sort_values(by=['linearSvrOPS'], ascending=False)
print(weightedOPSStats2017)
# weightedOPSStats2017.to_csv('OPSPredictions.csv')
# Out:
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#                   Name  Season  playerid  weightwOBA  weightwRC+  weightSLG  \
# 400       Gary Sanchez    2017     11442    2.864178    2.764769   3.621552
# 350         Mike Trout    2017     10155    2.608619    2.764769   2.243850
# 13         David Ortiz    2017       745    2.245458    2.089138   2.632658
# 140         Joey Votto    2017      4314    2.509086    2.361761   1.805157
# 47      Miguel Cabrera    2017      1744    2.237387    2.203718   2.057515
# ..                 ...     ...       ...         ...         ...        ...
# 232           JB Shuck    2017      6677   -2.112485   -2.134549  -1.631030
# 101  Charlie Culberson    2017      3298   -2.058683   -2.648187  -1.763078
# 156         John Baker    2017      4756   -2.381493   -2.332102  -2.628727
# 35          Mark Ellis    2017      1443   -2.865709   -2.766719  -2.892824
# 0          Jose Molina    2017        25   -3.296123   -3.122314  -3.274296
#
#      weightwRAA  weightOBP  weightISO  weightHR  opsPredicted  linearSvrOPS  \
# 400    1.162104   1.545896   3.773672  0.768254      1.032792      1.031297
# 350    3.639093   2.881775   1.883237  2.189414      0.985901      0.984056
# 13     2.817661   1.776613   2.566815  2.627515      0.973590      0.971543
# 140    3.390196   3.286242   1.210713  1.484177      0.970194      0.968703
# 47     2.784521   2.369071   1.380226  1.911593      0.955216      0.953733
# ..          ...        ...        ...       ...           ...           ...
# 232   -1.355075  -2.100001  -1.090606 -0.941411      0.547004      0.547785
# 101   -1.115343  -1.957583  -1.072181 -1.048265      0.543042      0.543675
# 156   -1.164700  -1.387912  -2.122423 -1.368827      0.504027      0.505144
# 35    -1.333922  -1.957583  -2.196124 -1.368827      0.466021      0.467200
# 0     -1.792232  -2.612706  -2.656756 -1.368827      0.417092      0.418522
#
#        svrOPS
# 400  0.932155
# 350  0.920277
# 13   0.886529
# 140  0.888382
# 47   0.883769
# ..        ...
# 232  0.609848
# 101  0.609985
# 156  0.588017
# 35   0.538490
# 0    0.517005
#
# [499 rows x 13 columns]
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
allData = pd.read_csv('all-np14-16.csv')


# In[238]:


# Some preprocessing on the column names
allData.astype({'Season': 'category'}).dtypes # set season to category instead of int
allData.set_index(['playerid', 'Name'])

# drop NaN values, which only come into play for pitchers running the bases (a very atypical occurrence)
allData = allData.dropna()

# dictionary assigning number of years in our data set played to each player
playerYears = dict() # dict of {'player ID': 'years in our data set that they played (1, 2, or 3)'}
pid, yearsPlayed = np.unique(allData['playerid'], return_counts=True)
for i in range(len(pid)):
    playerYears[pid[i]] = yearsPlayed[i]

# dictionary assigning names to player IDs
playerNames = dict() # dict where key is player ID, value is player name
# Assign each player ID to a name for future purposes
for i, r in allData.iterrows():
    playerNames[r['playerid']] = r['Name']

# assigns weights to each player and the data for that year. If played 2016-18, keep the weights of 0.6, 0.3, 0.1. If played two years, 0.7 and 0.3. If only played one year, assign 1 for now
for index, row in allData.iterrows():
    if playerYears[row['playerid']] == 3:
        continue
    elif playerYears[row['playerid']] == 2: # played in 16-17 or 17-18
        played1617 = False
        if row['Season'] == 2014:
            played1617 = True
            allData.set_value(index, 'weight', 0.3)
        elif row['Season'] == 2015:
            if played1617:
                allData.set_value(index, 'weight', 0.7)
            else:
                allData.set_value(index, 'weight', 0.3)
        else:
            allData.set_value(index, 'weight', 0.7)
    else:
        allData.set_value(index, 'weight', 1)


# sort all the rows by player ID first, then season. Makes it easier to figure out which player played which seasons
allData = allData.sort_values(by=['playerid', 'Season'])

# scale relevants stats
allData[['wRC', 'HR',  'PA', 'AB', 'R', 'H', '2B']] = preprocessing.scale(allData[['wRC', 'HR',  'PA', 'AB', 'R', 'H', '2B']])

# assign X and Y sets for regression
X = allData[['wRC', 'HR',  'PA', 'AB', 'R', 'H', '2B']].values
Y = allData[['RBI']].values

# add newly calculated weighted stats to our dataframe as columns
allData['weightwRC'] = allData['weight']*allData['wRC']
allData['weightHR'] = allData['weight']*allData['HR']
allData['weightPA'] = allData['weight']*allData['PA']
allData['weightAB'] = allData['weight']*allData['AB']
allData['weightR'] = allData['weight']*allData['R']
allData['weightH'] = allData['weight']*allData['H']
allData['weight2B'] = allData['weight']*allData['2B']


# sum up weighted averages by player, so that all years are combined
weightedRBIStats2017 = allData.groupby('playerid', as_index=False).sum()
weightedRBIStats2017 = weightedRBIStats2017[['playerid', 'weightwRC', 'weightHR', 'weightPA', 'weightAB', 'weightR' ,'weightH', 'weight2B']]

# we lost player names when doing the group by and sum, so get the player names and put it back in our new data frame
names = []
for i in pid:
    names.append(playerNames[i])
weightedRBIStats2017['Name'] = names
weightedRBIStats2017['Season'] = 2017

# move name and season columns to the front of the dataframe
cols = weightedRBIStats2017.columns.tolist()
cols = cols[-2:] + cols[:-2]
weightedRBIStats2017 = weightedRBIStats2017[cols]


# In[13]:


# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regressor = LinearRegression()
regressor.fit(X, Y)


# In[14]:


X_2017 = weightedRBIStats2017[['weightwRC', 'weightHR', 'weightPA', 'weightAB', 'weightR' ,'weightH', 'weight2B']].values
y_pred = regressor.predict(X_2017)


# In[15]:


y_pred_list = [] # list of y_pred so we can add it to a dataframe
for i in range(len(y_pred)):
    y_pred_list.append(y_pred[i][0])

weightedRBIStats2017['RBIsPredicted'] = y_pred_list

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
regr = LinearSVR(random_state=0)
regr.fit(X, Y)

# In[240]:

y_pred = regr.predict(X_2017)
weightedRBIStats2017['linearSvrRBI'] = y_pred

regr = SVR()
regr.fit(X, Y)

# In[240]:

y_pred = regr.predict(X_2017)
weightedRBIStats2017['svrRBI'] = y_pred

regr = linear_model.BayesianRidge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRBIStats2017['BayesRidgeRBI'] = y_pred

regr = linear_model.HuberRegressor()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRBIStats2017['HuberRegressorRBI'] = y_pred

regr = linear_model.Ridge()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRBIStats2017['RidgeRBI'] = y_pred

regr = linear_model.ARDRegression()
regr.fit(X, Y)

y_pred = regr.predict(X_2017)
weightedRBIStats2017['ARDRegressionRBI'] = y_pred


weightedRBIStats2017 = weightedRBIStats2017.sort_values(by=['linearSvrRBI'], ascending=False)
print(weightedRBIStats2017)
# weightedRBIStats2017.to_csv('RBIPredictions.csv')
# Out:
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#                   Name  Season  playerid  weightwRC  weightHR  weightPA  \
# 75         Nelson Cruz    2017      2434   2.178931  3.225898  1.397278
# 13         David Ortiz    2017       745   2.222837  2.627515  1.108016
# 327      Nolan Arenado    2017      9777   2.080143  2.798482  1.392727
# 67   Edwin Encarnacion    2017      2151   2.065507  2.937392  1.384927
# 171     Josh Donaldson    2017      5038   2.643602  2.627515  1.646237
# ..                 ...     ...       ...        ...       ...       ...
# 358      Rafael Ortega    2017     10323  -1.476235 -1.261973 -1.609091
# 41     Shane Victorino    2017      1677  -1.403059 -1.261973 -1.596091
# 318       Craig Gentry    2017      9571  -1.220118 -1.368827 -1.245077
# 399         Tyler Holt    2017     11391  -1.293294 -1.368827 -1.570090
# 35          Mark Ellis    2017      1443  -1.732353 -1.368827 -1.609091
#
#      weightAB   weightR   weightH  weight2B  RBIsPredicted  linearSvrRBI  \
# 75   1.357779  1.706095  1.525262  0.547439     113.884102    111.842518
# 13   0.927956  0.950507  1.217905  2.287351     115.458393    110.988786
# 327  1.409241  2.173641  1.602101  1.731837     110.242401    107.596751
# 67   1.176572  1.781236  1.059571  1.218248     109.494032    107.178511
# 171  1.367201  2.783120  1.471707  1.448839     102.689542    103.883513
# ..        ...       ...       ...       ...            ...           ...
# 358 -1.590096 -1.186846 -1.464474 -1.339212      12.669453     11.808871
# 41  -1.640834 -1.395572 -1.511043 -1.758468      12.225473     11.525985
# 318 -1.249427 -0.602414 -1.091922 -1.548840      12.116942     11.147400
# 399 -1.633586 -1.312082 -1.487759 -1.653654       9.283509     10.649313
# 35  -1.640834 -1.562553 -1.720604 -1.548840      11.515043      9.370283
#
#         svrRBI
# 75   91.510445
# 13   89.991720
# 327  93.319160
# 67   94.945386
# 171  87.635839
# ..         ...
# 358  19.458771
# 41   20.985694
# 318  20.066734
# 399  20.041024
# 35   21.779372
#
# [499 rows x 13 columns]
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\edyua\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
weightedRBIStats2017.reset_index()
dfa = weightedRBIStats2019.join(weightedAvgStats2017, how='outer', lsuffix='playerid', rsuffix='playerid')
dfa = dfa.join(weightedHRStats2017, how='outer', lsuffix='playerid', rsuffix='playerid')
dfa = dfa.join(weightedOPSStats2017, how='outer', lsuffix='playerid', rsuffix='playerid')
dfa = dfa.join(weightedRunStats2017, how='outer', lsuffix='playerid', rsuffix='playerid')
print(dfa)
dfa.to_csv('allPredictions2017.csv')
# Out:
#       Nameplayerid  Seasonplayerid  playeridplayerid  weightwRCplayerid  \
# 0      Jose Molina            2017                25          -1.805530
# 1    Brian Roberts            2017               166          -0.781058
# 2     Will Venable            2017               211          -0.380823
# 3     Paul Konerko            2017               242          -1.439647
# 4        Adam Dunn            2017               319           0.353177
# ..             ...             ...               ...                ...
# 494   Jung Ho Kang            2017             17182           0.269024
# 495   Alex Bregman            2017             17678          -0.927412
# 496  Byung-ho Park            2017             18497          -1.110353
# 497   Hyun Soo Kim            2017             18718          -0.122470
# 498     Dae-Ho Lee            2017             18722          -0.634705
#
#      weightHRplayerid  weightPAplayerid weightABplayerid  weightRplayerid  \
# 0           -1.368827         -1.316579        -1.300165        -2.021750
# 1           -0.834557         -0.660054        -0.633323        -0.518924
# 2           -0.372509         -0.119121        -0.116882        -0.223689
# 3           -0.834557         -1.466085        -1.423386        -1.562553
# 4            0.981963          0.399488         0.178484        -0.143217
# ..                ...               ...              ...              ...
# 494          0.682771         -0.327890        -0.402103        -0.122344
# 495         -0.513994         -1.511587        -1.474124        -0.894630
# 496         -0.086578         -1.336080        -1.372648        -1.019866
# 497         -0.727703         -0.673054        -0.720303        -0.685904
# 498          0.127130         -0.861562        -0.814530        -0.811140
#
#      weightHplayerid  weight2Bplayerid  ...  weightWRC  weightPAplayerid  \
# 0          -1.534328         -1.968096  ...  -1.805530         -1.316579
# 1          -0.719369         -0.500700  ...  -0.781058         -0.660054
# 2          -0.250002         -0.489085  ...  -0.380823         -0.119121
# 3          -1.464474         -1.339212  ...  -1.439647         -1.466085
# 4          -0.276962         -0.291073  ...   0.353177          0.399488
# ..               ...               ...  ...        ...               ...
# 494        -0.300247         -0.029038  ...   0.269024         -0.327890
# 495        -1.231629         -0.815142  ...  -0.927412         -1.511587
# 496        -1.511043         -1.234398  ...  -1.110353         -1.336080
# 497        -0.323531         -0.500700  ...  -0.122470         -0.673054
# 498        -0.742653         -1.234398  ...  -0.634705         -0.861562
#
#      weightHplayerid weightABplayerid  weightRBIplayerid   weightG  \
# 0          -1.534328        -1.300165          -1.601194 -1.342056
# 1          -0.719369        -0.633323          -1.164275 -0.967410
# 2          -0.250002        -0.116882          -0.412582  0.431098
# 3          -1.464474        -1.423386          -1.124555 -1.307997
# 4          -0.276962         0.178484           0.543680  0.394939
# ..               ...              ...                ...       ...
# 494        -0.300247        -0.402103           0.416576 -0.323700
# 495        -1.231629        -1.474124          -0.647916 -2.397876
# 496        -1.511043        -1.372648          -1.045115 -1.955112
# 497        -0.323531        -0.720303          -1.124555 -0.831175
# 498        -0.742653        -0.814530          -0.052118 -0.524646
#
#      weight2Bplayerid  runsPredicted  linearSVRRuns    svrRuns
# 0           -1.968096      15.432793      15.528188  25.873187
# 1           -0.500700      39.031729      36.465627  34.595298
# 2           -0.489085      46.376408      46.312928  45.497317
# 3           -1.339212      18.451153      18.109859  21.323826
# 4           -0.291073      61.370237      59.926848  55.933909
# ..                ...            ...            ...        ...
# 494         -0.029038      52.579126      51.519363  49.657209
# 495         -0.815142      25.337199      23.783690  29.861150
# 496         -1.234398      27.351875      24.259974  24.530757
# 497         -0.500700      48.109144      46.585285  42.898593
# 498         -1.234398      33.985689      34.198932  35.679595
#
# [499 rows x 65 columns]
