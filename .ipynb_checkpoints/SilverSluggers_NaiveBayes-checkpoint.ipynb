# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn import preprocessing
import math

# %%
def make_prediction(position, league, year, model):

    train_data = pd.read_csv(league.lower() + '-' + position.lower() + '+2014.csv')
    if year == "2020":
        test_data = pd.read_csv('2020Predictions.csv')
    else:
        test_data = pd.read_csv(year + 'PredictionsAndActual.csv')

    years = [int(year) - 1, int(year) - 2, int(year) - 3]

    prev_year_data = train_data[train_data["Season"] == int(year) - 1]

    train_data = train_data[train_data["Season"].isin(years)]

    train_features = [ "R", "HR", "RBI", "AVG", "OPS"]
    if model == "linear":
        test_features = ["runsPredicted", "HRsPredicted", "RBIsPredicted", "AVGPredicted", "opsPredicted"]
    elif model == "linearSVR":
        test_features = ["linearSVRRuns", "linearSvrHR", "linearSvrRBI", "linearSvrAVG", "linearSvrOPS"]
    elif model == "SVR":
        test_features = ["svrRuns", "SvrHR", "svrRBI", "svrAVG", "svrOPS"]

    gnb = GaussianNB()

    gnb.fit(train_data[train_features].values, train_data["SS"])

    pred = gnb.predict_proba(test_data[test_features])

    players = {}

    max_prob = 0
    for i in range(len(pred)):
        if test_data.iloc[i, 0] in prev_year_data["Name"].values:
            players[test_data.iloc[i, 0]] = pred[i][1]

    players_sorted = sorted(players, key=players.get, reverse=True)

    return players_sorted

# %%
def recall(predictions, winners, year, value):
    counter = 0
    for league in winners:
        for position in winners[league]:
            if position == "ofs":
                for name in winners[league][position]['stats'][year]['names']:
                    try:
                        index_elem = predictions[league][position].index(name)
                        if index_elem + 1 < value*3:
                            counter = counter + 1
                    except ValueError:
                        continue
            else:
                try:
                    index_elem = predictions[league][position].index(winners[league][position]['stats'][year]['name'])
                    if index_elem + 1 < value:
                        counter = counter + 1
                except ValueError:
                    continue
    return counter

# %%
def ranking(predictions, winners, year):
    accum = 0
    for league in winners:
        for position in winners[league]:
            if position == 'ofs':
                for name in winners[league][position]['stats'][year]['names']:
                    try:
                        index_elem = predictions[league][position].index(name)
                        accum = accum + 1 / (math.ceil((index_elem + 1) / 3))
                    except ValueError:
                        continue
            else:
                try:
                    index_elem = predictions[league][position].index(winners[league][position]['stats'][year]['name'])
                    accum = accum + 1 / (index_elem + 1)
                except ValueError:
                    continue
    return accum

# %%
def print_winners(winners, model, year):

    players_c_al = make_prediction("C", "AL", year, model)
    players_c_nl = make_prediction("C", "NL", year, model)
    players_1b_al = make_prediction("1B", "AL", year, model)
    players_1b_nl = make_prediction("1B", "NL", year, model)
    players_2b_al = make_prediction("2B", "AL", year, model)
    players_2b_nl = make_prediction("2B", "NL", year, model)
    players_3b_al = make_prediction("3B", "AL", year, model)
    players_3b_nl = make_prediction("3B", "NL", year, model)
    players_ss_al = make_prediction("SS", "AL", year, model)
    players_ss_nl = make_prediction("SS", "NL", year, model)
    players_of_al = make_prediction("OF", "AL", year, model)
    players_of_nl = make_prediction("OF", "NL", year, model)
    players_dh_al = make_prediction("DH", "AL", year, model)

    predictions = {
        'al': {
            'c': players_c_al,
            '1b': players_1b_al,
            '2b': players_2b_al,
            '3b': players_3b_al,
            'ss': players_ss_al,
            'ofs': players_of_al,
            'dh': players_dh_al
        },
        'nl': {
            'c': players_c_nl,
            '1b': players_1b_nl,
            '2b': players_2b_nl,
            '3b': players_3b_nl,
            'ss': players_ss_nl,
            'ofs': players_of_nl
        }
    }

    print(year + " " + model + '-----------------------------------------')
    print('C')
    print('AL: ' + players_c_al[0] + ', ' + players_c_al[1] + ', ' + players_c_al[2] + ', ' + players_c_al[3] + ', ' + players_c_al[4])
    print('NL: ' + players_c_nl[0] + ', ' + players_c_nl[1] + ', ' + players_c_nl[2] + ', ' + players_c_nl[3] + ', ' + players_c_nl[4])
    print('1B')
    print('AL: ' + players_1b_al[0])
    print(players_1b_al[0:5])
    print('NL: ' + players_1b_nl[0])
    print(players_1b_nl[0:5])
    print('2B')
    print('AL: ' + players_2b_al[0])
    print(players_2b_al[0:5])
    print('NL: ' + players_2b_nl[0])
    print(players_2b_nl[0:5])
    print('3B')
    print('AL: ' + players_3b_al[0])
    print(players_3b_al[0:5])
    print('NL: ' + players_3b_nl[0])
    print(players_3b_nl[0:5])
    print('SS')
    print('AL: ' + players_ss_al[0])
    print(players_ss_al[0:5])
    print('NL: ' + players_ss_nl[0])
    print(players_ss_nl[0:5])
    print('OF')
    print('AL: ' + players_of_al[0] + ', ' + players_of_al[1] + ', ' + players_of_al[2])
    print(players_of_al[0:15])
    print('NL: ' + players_of_nl[0] + ', ' + players_of_nl[1] + ', ' + players_of_nl[2])
    print(players_of_nl[0:15])
    print('DH')
    print('AL: ' + players_dh_al[0])
    print(players_dh_al[0:5])
    
    

    if year != '2020':
        print('Recall')
        recall_1 = recall(predictions, winners, year, 1)
        recall_2 = recall(predictions, winners, year, 2)
        recall_3 = recall(predictions, winners, year, 3)
        recall_4 = recall(predictions, winners, year, 4)
        recall_5 = recall(predictions, winners, year, 5)
        print(recall_1)
        print(recall_2)
        print(recall_3)
        print(recall_4)
        print(recall_5)
        print('Ranking')
        rank = ranking(predictions, winners, year)
        print(rank)

# %%
winners = {
    'al': {
        '1b': {
            'file': 'al-1b+2014.csv',
            'stats': {
                '2014': { 'name': 'Jose Abreu'},
                '2015': { 'name': 'Miguel Cabrera'},
                '2016': { 'name': 'Miguel Cabrera'},
                '2017': { 'name': 'Eric Hosmer'},
                '2018': { 'name': 'Jose Abreu'},
                '2019': { 'name': 'Carlos Santana'}
            }
        },
        '2b': {
            'file': 'al-2b+2014.csv',
            'stats': {
                '2014': { 'name': 'Jose Altuve'},
                '2015': { 'name': 'Jose Altuve'},
                '2016': { 'name': 'Jose Altuve'},
                '2017': { 'name': 'Jose Altuve'},
                '2018': { 'name': 'Jose Altuve'},
                '2019': { 'name': 'DJ LeMahieu'}
            }
        },
        '3b': {
            'file': 'al-3b+2014.csv',
            'stats': {
                '2014': { 'name': 'Adrian Beltre'},
                '2015': { 'name': 'Josh Donaldson'},
                '2016': { 'name': 'Josh Donaldson'},
                '2017': { 'name': 'Jose Ramirez'},
                '2018': { 'name': 'Jose Ramirez'},
                '2019': { 'name': 'Alex Bregman'}
            }
        },
        'ss': {
            'file': 'al-ss+2014.csv',
            'stats': {
                '2014': { 'name': 'Alexei Ramirez'},
                '2015': { 'name': 'Xander Bogaerts'},
                '2016': { 'name': 'Xander Bogaerts'},
                '2017': { 'name': 'Francisco Lindor'},
                '2018': { 'name': 'Francisco Lindor'},
                '2019': { 'name': 'Xander Bogaerts'}

            }
        },
        'ofs': {
            'file': 'al-of+2014.csv',
            'stats': {
                '2014': {
                    'names': ['Jose Bautista', 'Mike Trout', 'Michael Brantley']

                },
                '2015': {
                    'names': ['Nelson Cruz', 'Mike Trout', 'J.D. Martinez']

                },
                '2016': {
                    'names': ['Mookie Betts', 'Mike Trout', 'Mark Trumbo']

                },
                '2017': {
                    'names': ['Aaron Judge', 'George Springer', 'Justin Upton']

                },
                '2018': {
                    'names': ['Mookie Betts', 'Mike Trout', 'J.D. Martinez']

                },
                '2019': {
                    'names': ['Mookie Betts', 'Mike Trout', 'George Springer']

                }
            }
        },
        'c': {
            'file': 'al-c+2014.csv',
            'stats': {
                '2014': { 'name': 'Yan Gomes'},
                '2015': { 'name': 'Brian McCann'},
                '2016': { 'name': 'Salvador Perez'},
                '2017': { 'name': 'Gary Sanchez'},
                '2018': { 'name': 'Salvador Perez'},
                '2019': { 'name': 'Mitch Garver'}
            }
        },
        'dh': {
            'file': 'al-dh+2014.csv',
            'stats': {
                '2014': { 'name': 'Victor Martinez'},
                '2015': { 'name': 'Kendrys Morales'},
                '2016': { 'name': 'David Ortiz'},
                '2017': { 'name': 'Nelson Cruz'},
                '2018': { 'name': 'J.D. Martinez'},
                '2019': { 'name': 'Nelson Cruz'}
            }
        }
    },
    'nl': {
        '1b': {
            'file': 'nl-1b+2014.csv',
            'stats': {
                '2014': { 'name': 'Adrian Gonzalez'},
                '2015': { 'name': 'Paul Goldschmidt'},
                '2016': { 'name': 'Anthony Rizzo'},
                '2017': { 'name': 'Paul Goldschmidt'},
                '2018': { 'name': 'Paul Goldschmidt'},
                '2019': { 'name': 'Freddie Freeman'}
            }
        },
        '2b': {
            'file': 'nl-2b+2014.csv',
            'stats': {
                '2014': { 'name': 'Neil Walker'},
                '2015': { 'name': 'Dee Gordon'},
                '2016': { 'name': 'Daniel Murphy'},
                '2017': { 'name': 'Daniel Murphy'},
                '2018': { 'name': 'Javier Baez'},
                '2019': { 'name': 'Ozzie Albies'}
            }
        },
        '3b': {
            'file': 'nl-3b+2014.csv',
            'stats': {
                '2014': { 'name': 'Anthony Rendon'},
                '2015': { 'name': 'Nolan Arenado'},
                '2016': { 'name': 'Nolan Arenado'},
                '2017': { 'name': 'Nolan Arenado'},
                '2018': { 'name': 'Nolan Arenado'},
                '2019': { 'name': 'Anthony Rendon'}
            }
        },
        'ss': {
            'file': 'nl-ss+2014.csv',
            'stats': {
                '2014': { 'name': 'Ian Desmond'},
                '2015': { 'name': 'Brandon Crawford'},
                '2016': { 'name': 'Corey Seager'},
                '2017': { 'name': 'Corey Seager'},
                '2018': { 'name': 'Trevor Story'},
                '2019': { 'name': 'Trevor Story'}
            }
        },
        'ofs': {
            'file': 'nl-of+2014.csv',
            'stats': {
                '2014': {
                    'names': ['Andrew McCutchen', 'Giancarlo Stanton', 'Justin Upton']

                },
                '2015': {
                    'names': ['Andrew McCutchen', 'Bryce Harper', 'Carlos Gonzalez']

                },
                '2016': {
                    'names': ['Christian Yelich', 'Yoenis Cespedes', 'Charlie Blackmon']

                },
                '2017': {
                    'names': ['Marcell Ozuna', 'Giancarlo Stanton', 'Charlie Blackmon']

                },
                '2018': {
                    'names': ['Christian Yelich', 'Nick Markakis', 'David Peralta']

                },
                '2019': {
                    'names': ['Cody Bellinger', 'Christian Yelich', 'Ronald Acuna Jr.']

                }
            }
        },
        'c': {
            'file': 'nl-c+2014.csv',
            'stats': {
                '2014': { 'name': 'Buster Posey'},
                '2015': { 'name': 'Buster Posey'},
                '2016': { 'name': 'Wilson Ramos'},
                '2017': { 'name': 'Buster Posey'},
                '2018': { 'name': 'J.T. Realmuto'},
                '2019': { 'name': 'J.T. Realmuto'}
            }
        }
    }
}

# %%
print_winners(winners, "linear", "2017")
print_winners(winners, "linearSVR", "2017")
print_winners(winners, "SVR", "2017")

print_winners(winners, "linear", "2018")
print_winners(winners, "linearSVR", "2018")
print_winners(winners, "SVR", "2018")

print_winners(winners, "linear", "2019")
print_winners(winners, "linearSVR", "2019")
print_winners(winners, "SVR", "2019")

print_winners(winners, "linear", "2020")
print_winners(winners, "linearSVR", "2020")
print_winners(winners, "SVR", "2020")
# Out:
# 2017 linear-----------------------------------------
# C
# AL: Evan Gattis, Russell Martin, Salvador Perez, Brian McCann, Jonathan Lucroy
# NL: Willson Contreras, Buster Posey, Jonathan Lucroy, Devin Mesoraco, Yasmani Grandal
# 1B
# AL: Miguel Cabrera
# ['Miguel Cabrera', 'Edwin Encarnacion', 'Jose Abreu', 'Chris Davis', 'Carlos Santana']
# NL: Anthony Rizzo
# ['Anthony Rizzo', 'Paul Goldschmidt', 'Joey Votto', 'Freddie Freeman', 'Chris Carter']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Robinson Cano', 'Ian Kinsler', 'Jason Kipnis', 'Dustin Pedroia']
# NL: Matt Carpenter
# ['Matt Carpenter', 'Daniel Murphy', 'Jean Segura', 'Ben Zobrist', 'DJ LeMahieu']
# 3B
# AL: Josh Donaldson
# ['Josh Donaldson', 'Manny Machado', 'Adrian Beltre', 'Kyle Seager', 'Evan Longoria']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Kris Bryant', 'Matt Carpenter', 'Justin Turner', 'Jonathan Villar']
# SS
# AL: Xander Bogaerts
# ['Xander Bogaerts', 'Carlos Correa', 'Manny Machado', 'Francisco Lindor', 'Troy Tulowitzki']
# NL: Corey Seager
# ['Corey Seager', 'Trevor Story', 'Asdrubal Cabrera', 'Addison Russell', 'Brandon Crawford']
# OF
# AL: Nelson Cruz, Mike Trout, Mookie Betts
# ['Nelson Cruz', 'Mike Trout', 'Mookie Betts', 'J.D. Martinez', 'Mark Trumbo', 'Khris Davis', 'Jose Bautista', 'Justin Upton', 'Carlos Beltran', 'Adam Jones', 'George Springer', 'Kole Calhoun', 'Ian Desmond', 'Melky Cabrera', 'Michael Brantley']
# NL: Kris Bryant, Yoenis Cespedes, Bryce Harper
# ['Kris Bryant', 'Yoenis Cespedes', 'Bryce Harper', 'Matt Kemp', 'Carlos Gonzalez', 'Ryan Braun', 'Charlie Blackmon', 'Andrew McCutchen', 'Adam Duvall', 'Curtis Granderson', 'Jay Bruce', 'Christian Yelich', 'Giancarlo Stanton', 'Yasmany Tomas', 'Joc Pederson']
# DH
# AL: David Ortiz
# ['David Ortiz', 'Edwin Encarnacion', 'Mark Trumbo', 'Albert Pujols', 'Nelson Cruz']
# Recall
# 3
# 6
# 8
# 10
# 12
# Ranking
# 6.424908424908425
# 2017 linearSVR-----------------------------------------
# C
# AL: Evan Gattis, Russell Martin, Brian McCann, Salvador Perez, Jonathan Lucroy
# NL: Willson Contreras, Buster Posey, Jonathan Lucroy, Devin Mesoraco, Yasmani Grandal
# 1B
# AL: Miguel Cabrera
# ['Miguel Cabrera', 'Edwin Encarnacion', 'Jose Abreu', 'Carlos Santana', 'Chris Davis']
# NL: Anthony Rizzo
# ['Anthony Rizzo', 'Freddie Freeman', 'Joey Votto', 'Paul Goldschmidt', 'Chris Carter']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Robinson Cano', 'Ian Kinsler', 'Dustin Pedroia', 'Jason Kipnis']
# NL: Matt Carpenter
# ['Matt Carpenter', 'Daniel Murphy', 'Ben Zobrist', 'Jean Segura', 'DJ LeMahieu']
# 3B
# AL: Josh Donaldson
# ['Josh Donaldson', 'Manny Machado', 'Adrian Beltre', 'Kyle Seager', 'Evan Longoria']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Matt Carpenter', 'Justin Turner', 'Jonathan Villar', 'Martin Prado']
# SS
# AL: Xander Bogaerts
# ['Xander Bogaerts', 'Carlos Correa', 'Manny Machado', 'Brad Miller', 'Francisco Lindor']
# NL: Corey Seager
# ['Corey Seager', 'Trevor Story', 'Asdrubal Cabrera', 'Addison Russell', 'Brandon Crawford']
# OF
# AL: Nelson Cruz, Mike Trout, Mookie Betts
# ['Nelson Cruz', 'Mike Trout', 'Mookie Betts', 'J.D. Martinez', 'Mark Trumbo', 'Khris Davis', 'Jose Bautista', 'Justin Upton', 'George Springer', 'Carlos Beltran', 'Adam Jones', 'Kole Calhoun', 'Ian Desmond', 'Melky Cabrera', 'Michael Brantley']
# NL: Kris Bryant, Yoenis Cespedes, Bryce Harper
# ['Kris Bryant', 'Yoenis Cespedes', 'Bryce Harper', 'Carlos Gonzalez', 'Matt Kemp', 'Charlie Blackmon', 'Ryan Braun', 'Andrew McCutchen', 'Adam Duvall', 'Curtis Granderson', 'Jay Bruce', 'Christian Yelich', 'Giancarlo Stanton', 'Yasmany Tomas', 'Joc Pederson']
# DH
# AL: David Ortiz
# ['David Ortiz', 'Edwin Encarnacion', 'Nelson Cruz', 'Mark Trumbo', 'Carlos Santana']
# Recall
# 3
# 6
# 9
# 10
# 12
# Ranking
# 6.51935286935287
# 2017 SVR-----------------------------------------
# C
# AL: Evan Gattis, Russell Martin, Salvador Perez, Brian McCann, Jonathan Lucroy
# NL: Devin Mesoraco, Willson Contreras, Buster Posey, Jonathan Lucroy, Yasmani Grandal
# 1B
# AL: Miguel Cabrera
# ['Miguel Cabrera', 'Edwin Encarnacion', 'Jose Abreu', 'Carlos Santana', 'Chris Davis']
# NL: Anthony Rizzo
# ['Anthony Rizzo', 'Freddie Freeman', 'Joey Votto', 'Paul Goldschmidt', 'Chris Carter']
# 2B
# AL: Robinson Cano
# ['Robinson Cano', 'Brian Dozier', 'Jose Altuve', 'Ian Kinsler', 'Jason Kipnis']
# NL: Matt Carpenter
# ['Matt Carpenter', 'Daniel Murphy', 'Ben Zobrist', 'Jean Segura', 'DJ LeMahieu']
# 3B
# AL: Josh Donaldson
# ['Josh Donaldson', 'Manny Machado', 'Kyle Seager', 'Adrian Beltre', 'Todd Frazier']
# NL: Kris Bryant
# ['Kris Bryant', 'Nolan Arenado', 'Matt Carpenter', 'Justin Turner', 'Martin Prado']
# SS
# AL: Manny Machado
# ['Manny Machado', 'Carlos Correa', 'Xander Bogaerts', 'Brad Miller', 'Marcus Semien']
# NL: Corey Seager
# ['Corey Seager', 'Trevor Story', 'Addison Russell', 'Asdrubal Cabrera', 'Jonathan Villar']
# OF
# AL: Nelson Cruz, Mike Trout, Mark Trumbo
# ['Nelson Cruz', 'Mike Trout', 'Mark Trumbo', 'J.D. Martinez', 'Mookie Betts', 'Justin Upton', 'Jose Bautista', 'Khris Davis', 'Adam Jones', 'George Springer', 'Carlos Beltran', 'Kole Calhoun', 'Ian Desmond', 'Melky Cabrera', 'Michael Brantley']
# NL: Kris Bryant, Yoenis Cespedes, Carlos Gonzalez
# ['Kris Bryant', 'Yoenis Cespedes', 'Carlos Gonzalez', 'Bryce Harper', 'Matt Kemp', 'Adam Duvall', 'Ryan Braun', 'Charlie Blackmon', 'Jay Bruce', 'Andrew McCutchen', 'Curtis Granderson', 'Christian Yelich', 'Yasmany Tomas', 'Joc Pederson', 'Giancarlo Stanton']
# DH
# AL: David Ortiz
# ['David Ortiz', 'Edwin Encarnacion', 'Nelson Cruz', 'Carlos Santana', 'Mark Trumbo']
# Recall
# 1
# 4
# 8
# 10
# 11
# Ranking
# 5.111706349206349
# 2018 linear-----------------------------------------
# C
# AL: Gary Sanchez, Salvador Perez, Mike Zunino, Evan Gattis, Brian McCann
# NL: Buster Posey, Willson Contreras, Austin Barnes, Tyler Flowers, Kurt Suzuki
# 1B
# AL: Jose Abreu
# ['Jose Abreu', 'Eric Hosmer', 'Trey Mancini', 'Miguel Cabrera', 'Yuli Gurriel']
# NL: Joey Votto
# ['Joey Votto', 'Paul Goldschmidt', 'Anthony Rizzo', 'Cody Bellinger', 'Freddie Freeman']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Jose Ramirez', 'Robinson Cano', 'Jonathan Schoop', 'Brian Dozier']
# NL: Daniel Murphy
# ['Daniel Murphy', 'DJ LeMahieu', 'Cesar Hernandez', 'Dee Gordon', 'Asdrubal Cabrera']
# 3B
# AL: Josh Donaldson
# ['Josh Donaldson', 'Jose Ramirez', 'Adrian Beltre', 'Joey Gallo', 'Miguel Sano']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Kris Bryant', 'Justin Turner', 'Anthony Rendon', 'Jake Lamb']
# SS
# AL: Francisco Lindor
# ['Francisco Lindor', 'Didi Gregorius', 'Elvis Andrus', 'Carlos Correa', 'Jean Segura']
# NL: Corey Seager
# ['Corey Seager', 'Paul DeJong', 'Trevor Story', 'Javier Baez', 'Zack Cozart']
# OF
# AL: Aaron Judge, J.D. Martinez, Khris Davis
# ['Aaron Judge', 'J.D. Martinez', 'Khris Davis', 'Mike Trout', 'Justin Upton', 'George Springer', 'Mookie Betts', 'Jay Bruce', 'Trey Mancini', 'Adam Jones', 'Corey Dickerson', 'Andrew Benintendi', 'Melky Cabrera', 'Steven Souza Jr.', 'Kole Calhoun']
# NL: Giancarlo Stanton, Charlie Blackmon, J.D. Martinez
# ['Giancarlo Stanton', 'Charlie Blackmon', 'J.D. Martinez', 'Cody Bellinger', 'Marcell Ozuna', 'Bryce Harper', 'Andrew McCutchen', 'Jay Bruce', 'Tommy Pham', 'Adam Duvall', 'Christian Yelich', 'Domingo Santana', 'Chris Taylor', 'Matt Kemp', 'Carlos Gonzalez']
# DH
# AL: Nelson Cruz
# ['Nelson Cruz', 'Edwin Encarnacion', 'Kendrys Morales', 'Corey Dickerson', 'Mark Trumbo']
# Recall
# 5
# 9
# 11
# 12
# 12
# Ranking
# 8.414224664224664
# 2018 linearSVR-----------------------------------------
# C
# AL: Gary Sanchez, Salvador Perez, Mike Zunino, Evan Gattis, Brian McCann
# NL: Buster Posey, Willson Contreras, Austin Barnes, Tyler Flowers, Alex Avila
# 1B
# AL: Jose Abreu
# ['Jose Abreu', 'Eric Hosmer', 'Trey Mancini', 'Miguel Cabrera', 'Yuli Gurriel']
# NL: Joey Votto
# ['Joey Votto', 'Paul Goldschmidt', 'Anthony Rizzo', 'Cody Bellinger', 'Freddie Freeman']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Jose Ramirez', 'Robinson Cano', 'Jonathan Schoop', 'Brian Dozier']
# NL: Daniel Murphy
# ['Daniel Murphy', 'DJ LeMahieu', 'Cesar Hernandez', 'Dee Gordon', 'Asdrubal Cabrera']
# 3B
# AL: Josh Donaldson
# ['Josh Donaldson', 'Jose Ramirez', 'Adrian Beltre', 'Joey Gallo', 'Miguel Sano']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Kris Bryant', 'Jake Lamb', 'Anthony Rendon', 'Jhonny Peralta']
# SS
# AL: Francisco Lindor
# ['Francisco Lindor', 'Elvis Andrus', 'Didi Gregorius', 'Carlos Correa', 'Jean Segura']
# NL: Corey Seager
# ['Corey Seager', 'Paul DeJong', 'Trevor Story', 'Zack Cozart', 'Asdrubal Cabrera']
# OF
# AL: Aaron Judge, J.D. Martinez, Khris Davis
# ['Aaron Judge', 'J.D. Martinez', 'Khris Davis', 'Mike Trout', 'Justin Upton', 'George Springer', 'Mookie Betts', 'Jay Bruce', 'Trey Mancini', 'Adam Jones', 'Corey Dickerson', 'Andrew Benintendi', 'Melky Cabrera', 'Steven Souza Jr.', 'Kole Calhoun']
# NL: Giancarlo Stanton, Charlie Blackmon, J.D. Martinez
# ['Giancarlo Stanton', 'Charlie Blackmon', 'J.D. Martinez', 'Cody Bellinger', 'Marcell Ozuna', 'Bryce Harper', 'Andrew McCutchen', 'Jay Bruce', 'Tommy Pham', 'Christian Yelich', 'Adam Duvall', 'Chris Taylor', 'Domingo Santana', 'Carlos Gonzalez', 'Matt Kemp']
# DH
# AL: Nelson Cruz
# ['Nelson Cruz', 'Edwin Encarnacion', 'Kendrys Morales', 'Corey Dickerson', 'Mark Trumbo']
# Recall
# 5
# 9
# 11
# 12
# 12
# Ranking
# 8.414224664224664
# 2018 SVR-----------------------------------------
# C
# AL: Gary Sanchez, Salvador Perez, Mike Zunino, Evan Gattis, Brian McCann
# NL: Willson Contreras, Buster Posey, Yasmani Grandal, Austin Barnes, Kurt Suzuki
# 1B
# AL: Jose Abreu
# ['Jose Abreu', 'Eric Hosmer', 'Carlos Santana', 'Joey Gallo', 'Trey Mancini']
# NL: Anthony Rizzo
# ['Anthony Rizzo', 'Paul Goldschmidt', 'Joey Votto', 'Freddie Freeman', 'Cody Bellinger']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Robinson Cano', 'Brian Dozier', 'Jonathan Schoop', 'Jose Ramirez']
# NL: Daniel Murphy
# ['Daniel Murphy', 'DJ LeMahieu', 'Brandon Phillips', 'Cesar Hernandez', 'Asdrubal Cabrera']
# 3B
# AL: Josh Donaldson
# ['Josh Donaldson', 'Jose Ramirez', 'Adrian Beltre', 'Joey Gallo', 'Manny Machado']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Kris Bryant', 'Jake Lamb', 'Anthony Rendon', 'Justin Turner']
# SS
# AL: Francisco Lindor
# ['Francisco Lindor', 'Carlos Correa', 'Didi Gregorius', 'Elvis Andrus', 'Xander Bogaerts']
# NL: Corey Seager
# ['Corey Seager', 'Trevor Story', 'Paul DeJong', 'Zack Cozart', 'Javier Baez']
# OF
# AL: Justin Upton, Khris Davis, Mike Trout
# ['Justin Upton', 'Khris Davis', 'Mike Trout', 'George Springer', 'Jay Bruce', 'J.D. Martinez', 'Mookie Betts', 'Aaron Judge', 'Adam Jones', 'Trey Mancini', 'Corey Dickerson', 'Andrew Benintendi', 'Jose Bautista', 'Kole Calhoun', 'Steven Souza Jr.']
# NL: Giancarlo Stanton, Charlie Blackmon, Cody Bellinger
# ['Giancarlo Stanton', 'Charlie Blackmon', 'Cody Bellinger', 'Marcell Ozuna', 'Jay Bruce', 'J.D. Martinez', 'Bryce Harper', 'Adam Duvall', 'Andrew McCutchen', 'Tommy Pham', 'Christian Yelich', 'Chris Taylor', 'Curtis Granderson', 'Matt Kemp', 'Domingo Santana']
# DH
# AL: Nelson Cruz
# ['Nelson Cruz', 'Edwin Encarnacion', 'Kendrys Morales', 'Mark Trumbo', 'Corey Dickerson']
# Recall
# 5
# 10
# 11
# 12
# 12
# Ranking
# 8.584498834498834
# 2019 linear-----------------------------------------
# C
# AL: Gary Sanchez, Mike Zunino, Welington Castillo, Robinson Chirinos, Wilson Ramos
# NL: J.T. Realmuto, Yasmani Grandal, Wilson Ramos, Willson Contreras, Buster Posey
# 1B
# AL: Jose Abreu
# ['Jose Abreu', 'Justin Smoak', 'Matt Olson', 'Miguel Cabrera', 'Trey Mancini']
# NL: Paul Goldschmidt
# ['Paul Goldschmidt', 'Max Muncy', 'Anthony Rizzo', 'Freddie Freeman', 'Joey Votto']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Whit Merrifield', 'Joey Wendle', 'Robinson Cano', 'Gleyber Torres']
# NL: Javier Baez
# ['Javier Baez', 'Scooter Gennett', 'Brian Dozier', 'Asdrubal Cabrera', 'DJ LeMahieu']
# 3B
# AL: Jose Ramirez
# ['Jose Ramirez', 'Alex Bregman', 'Matt Chapman', 'Josh Donaldson', 'Mike Moustakas']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Max Muncy', 'Anthony Rendon', 'Matt Carpenter', 'Eugenio Suarez']
# SS
# AL: Francisco Lindor
# ['Francisco Lindor', 'Didi Gregorius', 'Xander Bogaerts', 'Manny Machado', 'Carlos Correa']
# NL: Manny Machado
# ['Manny Machado', 'Trevor Story', 'Javier Baez', 'Corey Seager', 'Chris Taylor']
# OF
# AL: J.D. Martinez, Mike Trout, Mookie Betts
# ['J.D. Martinez', 'Mike Trout', 'Mookie Betts', 'Aaron Judge', 'Justin Upton', 'Nicholas Castellanos', 'Joey Gallo', 'Mitch Haniger', 'Andrew McCutchen', 'George Springer', 'Andrew Benintendi', 'Tommy Pham', 'Shin-Soo Choo', 'Trey Mancini', 'Eddie Rosario']
# NL: Christian Yelich, Charlie Blackmon, Bryce Harper
# ['Christian Yelich', 'Charlie Blackmon', 'Bryce Harper', 'Cody Bellinger', 'David Peralta', 'Marcell Ozuna', 'Ronald Acuna Jr.', 'Juan Soto', 'Andrew McCutchen', 'Rhys Hoskins', 'Tommy Pham', 'Michael Conforto', 'Nick Markakis', 'Corey Dickerson', 'Jose Martinez']
# DH
# AL: J.D. Martinez
# ['J.D. Martinez', 'Khris Davis', 'Nelson Cruz', 'Edwin Encarnacion', 'C.J. Cron']
# Recall
# 4
# 7
# 11
# 13
# 13
# Ranking
# 7.527777777777778
# 2019 linearSVR-----------------------------------------
# C
# AL: Gary Sanchez, Mike Zunino, Robinson Chirinos, Welington Castillo, Wilson Ramos
# NL: J.T. Realmuto, Yasmani Grandal, Wilson Ramos, Willson Contreras, Buster Posey
# 1B
# AL: Jose Abreu
# ['Jose Abreu', 'Justin Smoak', 'Matt Olson', 'Miguel Cabrera', 'Trey Mancini']
# NL: Max Muncy
# ['Max Muncy', 'Anthony Rizzo', 'Jesus Aguilar', 'Cody Bellinger', 'Matt Carpenter']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'Whit Merrifield', 'Joey Wendle', 'Gleyber Torres', 'Robinson Cano']
# NL: Javier Baez
# ['Javier Baez', 'Scooter Gennett', 'Brian Dozier', 'Asdrubal Cabrera', 'DJ LeMahieu']
# 3B
# AL: Jose Ramirez
# ['Jose Ramirez', 'Alex Bregman', 'Matt Chapman', 'Josh Donaldson', 'Mike Moustakas']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Max Muncy', 'Matt Carpenter', 'Anthony Rendon', 'Eugenio Suarez']
# SS
# AL: Francisco Lindor
# ['Francisco Lindor', 'Xander Bogaerts', 'Manny Machado', 'Didi Gregorius', 'Tim Anderson']
# NL: Manny Machado
# ['Manny Machado', 'Trevor Story', 'Javier Baez', 'Corey Seager', 'Chris Taylor']
# OF
# AL: J.D. Martinez, Mike Trout, Mookie Betts
# ['J.D. Martinez', 'Mike Trout', 'Mookie Betts', 'Aaron Judge', 'Nicholas Castellanos', 'Justin Upton', 'Mitch Haniger', 'Joey Gallo', 'Andrew McCutchen', 'George Springer', 'Andrew Benintendi', 'Tommy Pham', 'Shin-Soo Choo', 'Eddie Rosario', 'Trey Mancini']
# NL: Christian Yelich, Charlie Blackmon, Bryce Harper
# ['Christian Yelich', 'Charlie Blackmon', 'Bryce Harper', 'Cody Bellinger', 'David Peralta', 'Marcell Ozuna', 'Ronald Acuna Jr.', 'Juan Soto', 'Rhys Hoskins', 'Andrew McCutchen', 'Tommy Pham', 'Michael Conforto', 'Nick Markakis', 'Chris Taylor', 'Corey Dickerson']
# DH
# AL: J.D. Martinez
# ['J.D. Martinez', 'Khris Davis', 'Nelson Cruz', 'Edwin Encarnacion', 'C.J. Cron']
# Recall
# 4
# 8
# 10
# 12
# 12
# Ranking
# 7.5
# 2019 SVR-----------------------------------------
# C
# AL: Gary Sanchez, Robinson Chirinos, Wilson Ramos, Welington Castillo, Mike Zunino
# NL: Yasmani Grandal, J.T. Realmuto, Yadier Molina, Wilson Ramos, Willson Contreras
# 1B
# AL: Miguel Cabrera
# ['Miguel Cabrera', 'Yonder Alonso', 'Albert Pujols', 'Justin Smoak', 'Mitch Moreland']
# NL: Paul Goldschmidt
# ['Paul Goldschmidt', 'Freddie Freeman', 'Max Muncy', 'Matt Carpenter', 'Anthony Rizzo']
# 2B
# AL: Robinson Cano
# ['Robinson Cano', 'Jose Altuve', 'Brian Dozier', 'Ian Kinsler', 'Jonathan Schoop']
# NL: Asdrubal Cabrera
# ['Asdrubal Cabrera', 'Scooter Gennett', 'Daniel Murphy', 'Brian Dozier', 'Starlin Castro']
# 3B
# AL: Jose Ramirez
# ['Jose Ramirez', 'Josh Donaldson', 'Alex Bregman', 'Mike Moustakas', 'Eduardo Escobar']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Max Muncy', 'Matt Carpenter', 'Mike Moustakas', 'Eugenio Suarez']
# SS
# AL: Francisco Lindor
# ['Francisco Lindor', 'Manny Machado', 'Didi Gregorius', 'Xander Bogaerts', 'Jean Segura']
# NL: Sean Rodriguez
# ['Sean Rodriguez', 'Manny Machado', 'Trevor Story', 'Javier Baez', 'Brandon Crawford']
# OF
# AL: J.D. Martinez, Justin Upton, Shin-Soo Choo
# ['J.D. Martinez', 'Justin Upton', 'Shin-Soo Choo', 'Tommy Pham', 'Mike Trout', 'Michael Brantley', 'Aaron Hicks', 'Curtis Granderson', 'Marwin Gonzalez', 'Adam Jones', 'Andrew McCutchen', 'Avisail Garcia', 'Josh Reddick', 'Nicholas Castellanos', 'Melky Cabrera']
# NL: Bryce Harper, Christian Yelich, David Peralta
# ['Bryce Harper', 'Christian Yelich', 'David Peralta', 'Charlie Blackmon', 'Tommy Pham', 'Marcell Ozuna', 'Cody Bellinger', 'Rhys Hoskins', 'Andrew McCutchen', 'Ryan Braun', 'Ronald Acuna Jr.', 'Michael Conforto', 'Nick Markakis', 'Eric Thames', 'Juan Soto']
# DH
# AL: Nelson Cruz
# ['Nelson Cruz', 'J.D. Martinez', 'Khris Davis', 'Edwin Encarnacion', 'Shin-Soo Choo']
# Recall
# 2
# 5
# 8
# 10
# 10
# Ranking
# 5.552170868347339
# 2020 linear-----------------------------------------
# C
# AL: Gary Sanchez, Mitch Garver, Robinson Chirinos, Tom Murphy, James McCann
# NL: Yasmani Grandal, J.T. Realmuto, Willson Contreras, Wilson Ramos, Carson Kelly
# 1B
# AL: Trey Mancini
# ['Trey Mancini', 'Carlos Santana', 'Jose Abreu', 'Matt Olson', 'Yuli Gurriel']
# NL: Freddie Freeman
# ['Freddie Freeman', 'Paul Goldschmidt', 'Anthony Rizzo', 'Peter Alonso', 'Max Muncy']
# 2B
# AL: Whit Merrifield
# ['Whit Merrifield', 'Jose Altuve', 'DJ LeMahieu', 'Gleyber Torres', 'Jonathan Villar']
# NL: Ketel Marte
# ['Ketel Marte', 'Ozzie Albies', 'Max Muncy', 'Mike Moustakas', 'Cesar Hernandez']
# 3B
# AL: Alex Bregman
# ['Alex Bregman', 'Matt Chapman', 'Miguel Andujar', 'Jose Ramirez', 'Rafael Devers']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Eugenio Suarez', 'Anthony Rendon', 'Manny Machado', 'Eduardo Escobar']
# SS
# AL: Alex Bregman
# ['Alex Bregman', 'Xander Bogaerts', 'Francisco Lindor', 'Gleyber Torres', 'Marcus Semien']
# NL: Trevor Story
# ['Trevor Story', 'Javier Baez', 'Trea Turner', 'Kevin Newman', 'Amed Rosario']
# OF
# AL: Mike Trout, J.D. Martinez, Mookie Betts
# ['Mike Trout', 'J.D. Martinez', 'Mookie Betts', 'Austin Meadows', 'Nicholas Castellanos', 'George Springer', 'Jorge Soler', 'Trey Mancini', 'Giancarlo Stanton', 'Aaron Judge', 'Shin-Soo Choo', 'Michael Brantley', 'Tommy Pham', 'Whit Merrifield', 'Danny Santana']
# NL: Christian Yelich, Cody Bellinger, Bryce Harper
# ['Christian Yelich', 'Cody Bellinger', 'Bryce Harper', 'Charlie Blackmon', 'Ronald Acuna Jr.', 'Juan Soto', 'Nicholas Castellanos', 'Michael Conforto', 'Kris Bryant', 'Ketel Marte', 'Kyle Schwarber', 'Bryan Reynolds', 'Marcell Ozuna', 'J.D. Davis', 'Franmil Reyes']
# DH
# AL: J.D. Martinez
# ['J.D. Martinez', 'Nelson Cruz', 'Jorge Soler', 'Austin Meadows', 'Giancarlo Stanton']
# 2020 linearSVR-----------------------------------------
# C
# AL: Gary Sanchez, Mitch Garver, Robinson Chirinos, Tom Murphy, James McCann
# NL: Yasmani Grandal, J.T. Realmuto, Willson Contreras, Wilson Ramos, Carson Kelly
# 1B
# AL: Trey Mancini
# ['Trey Mancini', 'Carlos Santana', 'Jose Abreu', 'Matt Olson', 'Yuli Gurriel']
# NL: Freddie Freeman
# ['Freddie Freeman', 'Paul Goldschmidt', 'Anthony Rizzo', 'Josh Bell', 'Christian Walker']
# 2B
# AL: Whit Merrifield
# ['Whit Merrifield', 'DJ LeMahieu', 'Jose Altuve', 'Gleyber Torres', 'Jonathan Villar']
# NL: Ketel Marte
# ['Ketel Marte', 'Ozzie Albies', 'Max Muncy', 'Mike Moustakas', 'Cesar Hernandez']
# 3B
# AL: Alex Bregman
# ['Alex Bregman', 'Matt Chapman', 'Miguel Andujar', 'Jose Ramirez', 'Rafael Devers']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Eugenio Suarez', 'Anthony Rendon', 'Manny Machado', 'Eduardo Escobar']
# SS
# AL: Alex Bregman
# ['Alex Bregman', 'Xander Bogaerts', 'Francisco Lindor', 'Gleyber Torres', 'Marcus Semien']
# NL: Trevor Story
# ['Trevor Story', 'Javier Baez', 'Trea Turner', 'Kevin Newman', 'Amed Rosario']
# OF
# AL: Mike Trout, J.D. Martinez, Mookie Betts
# ['Mike Trout', 'J.D. Martinez', 'Mookie Betts', 'Austin Meadows', 'Nicholas Castellanos', 'George Springer', 'Jorge Soler', 'Trey Mancini', 'Giancarlo Stanton', 'Aaron Judge', 'Shin-Soo Choo', 'Michael Brantley', 'Whit Merrifield', 'Tommy Pham', 'Danny Santana']
# NL: Christian Yelich, Cody Bellinger, Charlie Blackmon
# ['Christian Yelich', 'Cody Bellinger', 'Charlie Blackmon', 'Ronald Acuna Jr.', 'Bryce Harper', 'Juan Soto', 'Nicholas Castellanos', 'Ketel Marte', 'Michael Conforto', 'Kris Bryant', 'Kyle Schwarber', 'Bryan Reynolds', 'Marcell Ozuna', 'J.D. Davis', 'Starling Marte']
# DH
# AL: J.D. Martinez
# ['J.D. Martinez', 'Nelson Cruz', 'Jorge Soler', 'Austin Meadows', 'Giancarlo Stanton']
# 2020 SVR-----------------------------------------
# C
# AL: Gary Sanchez, Mitch Garver, Robinson Chirinos, Travis d'Arnaud, James McCann
# NL: Yasmani Grandal, J.T. Realmuto, Willson Contreras, Wilson Ramos, Carson Kelly
# 1B
# AL: Carlos Santana
# ['Carlos Santana', 'Trey Mancini', 'Jose Abreu', 'Matt Olson', 'Yuli Gurriel']
# NL: Peter Alonso
# ['Peter Alonso', 'Freddie Freeman', 'Max Muncy', 'Paul Goldschmidt', 'Anthony Rizzo']
# 2B
# AL: Jose Altuve
# ['Jose Altuve', 'DJ LeMahieu', 'Gleyber Torres', 'Whit Merrifield', 'Jonathan Villar']
# NL: Ketel Marte
# ['Ketel Marte', 'Ozzie Albies', 'Max Muncy', 'Mike Moustakas', 'Starlin Castro']
# 3B
# AL: Alex Bregman
# ['Alex Bregman', 'Matt Chapman', 'Jose Ramirez', 'Miguel Andujar', 'Rafael Devers']
# NL: Nolan Arenado
# ['Nolan Arenado', 'Anthony Rendon', 'Eugenio Suarez', 'Manny Machado', 'Eduardo Escobar']
# SS
# AL: Alex Bregman
# ['Alex Bregman', 'Xander Bogaerts', 'Francisco Lindor', 'Gleyber Torres', 'Marcus Semien']
# NL: Trevor Story
# ['Trevor Story', 'Javier Baez', 'Corey Seager', 'Paul DeJong', 'Trea Turner']
# OF
# AL: J.D. Martinez, Mike Trout, Austin Meadows
# ['J.D. Martinez', 'Mike Trout', 'Austin Meadows', 'Mookie Betts', 'George Springer', 'Giancarlo Stanton', 'Trey Mancini', 'Jorge Soler', 'Nicholas Castellanos', 'Max Kepler', 'Shin-Soo Choo', 'Eddie Rosario', 'Aaron Judge', 'Danny Santana', 'Tommy Pham']
# NL: Cody Bellinger, Christian Yelich, Bryce Harper
# ['Cody Bellinger', 'Christian Yelich', 'Bryce Harper', 'Juan Soto', 'Charlie Blackmon', 'Ronald Acuna Jr.', 'Michael Conforto', 'Kyle Schwarber', 'Ketel Marte', 'Nicholas Castellanos', 'Kris Bryant', 'Marcell Ozuna', 'Joc Pederson', 'Yasiel Puig', 'Starling Marte']
# DH
# AL: J.D. Martinez
# ['J.D. Martinez', 'Nelson Cruz', 'Giancarlo Stanton', 'Jorge Soler', 'Austin Meadows']
